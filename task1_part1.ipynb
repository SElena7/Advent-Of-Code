# %%
file_path = 'AOC23 task1 part1.txt'
c = 0 
str_cal_val = ''
calibration_value = 0
with open(file_path, 'r') as file:
    
     for line in file:
            
            for letter in line:
                
                if(letter.isdigit()): 
                    if(letter != '\n'):
                        str_cal_val = str_cal_val + letter
                        calibration_value = int(str_cal_val)
                    else: 
                        print(calibration_value)
# Out:
#   File "<tokenize>", line 14
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
file_path = 'AOC23 task1 part1.txt'
c = 0 
str_cal_val = ''
calibration_value = 0
char_list = []
int_list = []

with open(file_path, 'r') as file:
    
     for line in file:
            char_list = list(line)
            for char in char_list:
                if (char.isdigit()):
                    
                    str_cal_val = str_cal_val + char
                    #calibration_value = int(str_cal_val)
                    
            int_list.append(str_cal_val)
            str_cal_val = ''
            #calibration_value = 0
                
    
    
print(int_list)   

calibration_value = 0

for number in int_list:
# Out:
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_11952\2093373012.py", line 36
#
#     ^
# IndentationError: expected an indented block

# %%
file_path = 'AOC23 task1 part1.txt'
c = 0 
str_cal_val = ''
calibration_value = ''
char_list = []
int_list = []
int_list2 = []
with open(file_path, 'r') as file:
    
     for line in file:
            char_list = list(line)
            for char in char_list:
                if (char.isdigit()):
                    
                    str_cal_val = str_cal_val + char
                    #calibration_value = int(str_cal_val)
                    
            int_list.append(str_cal_val)
            str_cal_val = ''
            #calibration_value = 0
print(int_list)   

for number in int_list:
    if (len(number)==1):
        calibration_value = number[0]+number[0]
        int_list2.append(int(calibration_value))
        calibration_value = ''
    else:
        calibration_value = number[0] + number[len(number)-1]
        int_list2.append(int(calibration_value))
        calibration_value = ''
    
    
    
        


print(sum(int_list2))
# Out:
# ['939', '656', '5', '72', '1', '49', '1', '285', '36', '1213', '461', '5', '59', '5', '1', '67', '45', '6', '56', '9', '9864', '172', '3476', '16', '8', '2', '65', '359', '29', '98', '757', '88', '1', '15', '2', '144', '47', '4', '3367', '97', '37', '83', '51', '84', '391', '9', '16', '6', '41', '7', '5281', '359', '4', '1', '264', '8', '32', '5698', '35', '8', '4', '1', '55', '49', '1', '537', '1', '7732', '4', '45', '1983', '785', '15477', '3843', '353', '78', '6', '143', '84', '452', '8', '29', '8', '2', '1', '5', '284', '27', '163', '685', '72', '481', '692', '31', '1', '2', '558256', '153', '717', '45', '32', '4', '384', '797', '98', '28', '8', '6773', '434', '456', '1', '75', '27733', '8', '2', '9', '6', '59', '7', '838', '955', '56356', '616', '95', '9412', '41', '7', '36', '899', '1', '7', '5', '5985', '814', '42', '3', '6', '4', '2', '3', '48', '1', '654', '81', '71', '6', '6', '29', '5', '8', '3', '29', '875', '561', '1872', '425', '819', '2251', '3399', '5', '625', '862', 
# ...
